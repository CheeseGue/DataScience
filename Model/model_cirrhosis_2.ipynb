# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# ライブラリ・データセットのインポート
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder

## 実行時間を調べるために使う
import datetime
import time
import math

start_time = time.time()

def changeHMS(s):
    h = math.floor(s / 3600)
    if h > 0:
        s = s - h * 3600
        indi_h = str(h) + 'h'
    else:
        indi_h = ''
    m = math.floor(s / 60)
    if m > 0:
        indi_m = str(m) + 'm'
    else:
        indi_m = ''
    s = math.floor(s % 60)
    time = indi_h + indi_m + str(s) + 's'
    return time

FILE_PATH = '/kaggle/input/playground-series-s3e26/'
OUTPUT_DIR = '/kaggle/working/'

train = pd.read_csv(FILE_PATH + 'train.csv')
test = pd.read_csv(FILE_PATH + 'test.csv')

test_id = test['id']

target = train['Status']

target_name = str(train.iloc[:, [18]].columns.tolist()) # カラム数-2の値が目的変数

df = pd.concat([train, test], axis=0)
df.reset_index(inplace=True)

# 説明変数をデータ型ごとに代入する
numerical_features = df._get_numeric_data().columns
categorical_features = df.drop(numerical_features, axis=1).columns
numerical_features = numerical_features.drop('id')

# 前処理
# 欠損値の補完
def missing_values(df):

    return df

# 外れ値の削除
def outlier(df):

    return df

# MinMaxScaler(正規化)
def scaling(df):
    df_scale = df[numerical_features]
    sc = MinMaxScaler()
    df[numerical_features] = pd.DataFrame(sc.fit_transform(df_scale), columns = df_scale.columns)

    return df

# 特徴量エンジニアリング
# 特徴量の作成
def create_new_features(df):
    # 血小板減少症インジケーター
    threshold_platelets = 150 # 閾値
    df['thrombocytopenia'] = np.where(df['Platelets'] < threshold_platelets, 1, 0)

    # アルカリ性リン酸塩ホスファターゼの上昇指標：
    threshold_alk_phos_upper = 147
    threshold_alk_phos_lower = 44
    df['elevated_alk_phos'] = np.where((df['Alk_Phos'] > threshold_alk_phos_upper) | (df['Alk_Phos'] < threshold_alk_phos_lower), 1, 0)

    # 正常な銅レベル
    normal_copper_range = (62, 140)
    df['normal_copper'] = np.where((df['Copper'] >= normal_copper_range[0]) & (df['Copper'] <= normal_copper_range[1]), 1, 0)

    # アルブミンの正常範囲
    normal_albumin_range = (3.4, 5.4)
    df['normal_albumin'] = np.where((df['Albumin'] >= normal_albumin_range[1]), 1, 0)

    # 正常なビリルビンレベル
    normal_bilirubin_range = (0.2, 1.2)
    df['normal_bilirubin'] = np.where((df['Bilirubin'] >= normal_bilirubin_range[0]) & (df['Bilirubin'] <= normal_bilirubin_range[1]), 1, 0)

    # 診断日
    df['DiagnosisDays'] = df['Age'] - df['N_Days']

    # ビリルビン * アルブミン
    df['Bilirubin_Albumin'] = df['Bilirubin'] * df['Albumin']

    # 症状のスコア
    symptom_columns = ['Ascites', 'Hepatomegaly', 'Spiders']
    df['Symptom_Score'] = df[symptom_columns].sum(axis=1)

    # 肝臓機能
    liver_columns = ['Bilirubin', 'Albumin', 'Alk_Phos', 'SGOT']
    df['Liver_Function_Index'] = df[liver_columns].mean(axis=1)

    # リスクスコア
    df['Risk_Score'] = df['Bilirubin'] + df['Albumin'] - df['Alk_Phos']

    # 時間特徴量
    df['Diag_Year'] = (df['N_Days'] / 365).astype(int)
    df['Diag_Month'] = ((df['N_Days'] % 365) / 30).astype(int)

    return df

# 年齢に関する特徴量の追加
def convert_days_to_years(age_in_days):
    days_in_year = 365.25
    age_in_years = age_in_days / days_in_year

    return age_in_years

def add_cols(df):
    age = list(df.Age)
    age_in_year = []
    for i in age:
        age_in_year.append(int(convert_days_to_years(i)))
    df['Age_in_year'] = pd.Series(age_in_year)

    return df

# カテゴリ変数のエンコーディング
# One-Hot Encoding
def one_hot_encoding(df, cat_cols):
    df = pd.get_dummies(df, columns=cat_cols)
    # 目的変数を数値化(int64)する
    df['Status'] = df['Status'].map({"C": 0, "CL": 1, "D": 2})
    # 一緒にラベルエンコーディングすると、1,2,3になってしまいモデル学習できないため分割する

    return df

# LabelEncoding
def label_encoder(df):
    categorical_columns = df.select_dtypes(include=['object']).columns
    for column in categorical_columns:
        df[column] = df[column].fillna('').astype('str') # 欠損値の補完をする
        label_encoder = LabelEncoder()
        df[column] = label_encoder.fit_transform(df[column])

    return df

# 特徴量の選択
# 特徴量の重要度評価
def feature_importance_evaluation(df):
    # データを対数変換する

    # 訓練データをX(説明変数)とy（目的変数）に分割する
    X = df.select_dtypes(include=['float', 'int'])
    X = X.drop(['Status'], axis=1) # 目的変数を指定する
    y = target # 目的変数を指定する

    for column in X.columns.tolist():
        X[column] = X[column].apply(lambda x: np.log(x + 1))

    # 特徴量の重要度評価
    lgb = LGBMClassifier(
        random_state=42,
    )

    lgb.fit(X, y)
    importance = lgb.feature_importances_

    feature_importance = pd.DataFrame(data=importance, index=X.columns, columns=['importance']) \
        .sort_values(ascending=True, by='importance')

    return feature_importance

# 特徴量の削除
def drop_columns(df):
    drop_list = [
#         'index'
    ]
    dropped_df = df.drop(columns=drop_list)

    return dropped_df

# データセットの更新
# 前処理
df = add_cols(df)
df = missing_values(df)
df = outlier(df)
# df = scaling(df) # 標準化したい時のみ実行する

# 特徴量エンジニアリング
df = create_new_features(df)
df = drop_columns(df)

cat_cols = ['Edema', 'Stage'] # One-Hot Encodingしたい水準数の少ないカラムを指定する
df = one_hot_encoding(df, cat_cols)
df = label_encoder(df)

train = df[df.loc[:, 'id'] < 7905]
test = df[df.loc[:, 'id'] >= 7905]

train_x = train.drop(columns=['Status', 'id'])
train_y = target
test_x = test.drop(columns=['Status', 'id'])

X = train_x.values
y = train_y.values
# y = y.astype(int)

df.head()

# ID削除
# df.drop("id", axis=1, inplace=True)

df.to_csv(OUTPUT_DIR + 'data.csv', index=False)

# 確認 (data_import.py)
def file_to_xy(filename):
    data = pd.read_csv(filename, index_col=0)
    print(f'読み込み完了 {filename}')
    train = data[:7905].reset_index(drop=True)
    test = data[7905:].reset_index(drop=True).drop('Status', axis=1)
    # 目的変数と説明変数に分割
    X = train.drop('Status', axis=1)
    y = train['Status'].values
    return data,test,train,X,y

filename = OUTPUT_DIR + 'data.csv'
data,test,train,X,y = file_to_xy(filename)
# Out:
# 読み込み完了 /kaggle/working/data.csv

# %%
train = train.copy()
train_x = X.copy()
train_y = y.copy()
test_x = test.copy()

# %%
# 評価指標
from sklearn.metrics import log_loss

# バリデーション
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold, StratifiedKFold, RepeatedStratifiedKFold

# ハイパーパラメータ
import optuna

# 機械学習モデル
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier, early_stopping

# %%
def objective_lgb(trial):
    """Define the objective function"""
    params = {
        'objective': trial.suggest_categorical('objective', ['multi_logloss']),
        'num_class': trial.suggest_categorical('num_class', [3]),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 50, 2000),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.01, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.01, 1.0),
        "random_state" : trial.suggest_categorical('random_state', [42]),
    }

    params = {
        'objective': trial.suggest_categorical('objective', ['multi_logloss']),
        'num_class': trial.suggest_categorical('num_class', [3]),
        'max_depth': trial.suggest_int('max_depth', 7, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 13, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.013, 0.04),
        'n_estimators': trial.suggest_int('n_estimators', 200, 500),
        'min_child_weight': trial.suggest_int('min_child_weight', 7, 10),
        'subsample': trial.suggest_float('subsample', 0.3, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.05, 0.2),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.05, 1.0),
        "random_state" : trial.suggest_categorical('random_state', [42]),
    }


    lgb = LGBMClassifier(**params, device = 'gpu', n_jobs = -1)
    cv = abs(cross_val_score(lgb, X_train, y_train, cv = skf,scoring='neg_log_loss').mean())
    return cv

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.85, random_state = 2610, stratify = y)
skf = RepeatedStratifiedKFold(n_splits = 3, n_repeats = 1, random_state = 2610)

# %%
# %%time
# study = optuna.create_study(direction='minimize')
# study.optimize(objective_lgb, n_trials=100, timeout=2000)
# Out:
# [I 2023-12-26 01:44:56,828] A new study created in memory with name: no-name-8f90f95c-16fa-4f6d-81a4-9276021d68c0
# [I 2023-12-26 01:45:08,856] Trial 0 finished with value: 0.6184527071917879 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 8, 'learning_rate': 0.3735559374800645, 'n_estimators': 1301, 'min_child_weight': 9, 'subsample': 0.44436432238250456, 'colsample_bytree': 0.8223050707360476, 'reg_alpha': 0.609734923848682, 'reg_lambda': 0.11958536292571609, 'random_state': 42}. Best is trial 0 with value: 0.6184527071917879.
# [I 2023-12-26 01:45:15,813] Trial 1 finished with value: 0.4873542544825821 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 8, 'learning_rate': 0.11776040000531743, 'n_estimators': 357, 'min_child_weight': 5, 'subsample': 0.7285812102054553, 'colsample_bytree': 0.1285251301063317, 'reg_alpha': 0.5364791586550435, 'reg_lambda': 0.28235847084721055, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:45:41,710] Trial 2 finished with value: 0.5155441494168325 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 6, 'learning_rate': 0.030830027026950285, 'n_estimators': 918, 'min_child_weight': 5, 'subsample': 0.8643155584802136, 'colsample_bytree': 0.517067217334383, 'reg_alpha': 0.5271368865685094, 'reg_lambda': 0.811823450160119, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:45:54,651] Trial 3 finished with value: 0.8181576964345404 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 9, 'learning_rate': 0.6703263821487151, 'n_estimators': 1344, 'min_child_weight': 8, 'subsample': 0.25536468021013753, 'colsample_bytree': 0.7781229448071829, 'reg_alpha': 0.029098407617678054, 'reg_lambda': 0.5528324001114457, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:46:03,417] Trial 4 finished with value: 0.6204656023047007 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 8, 'learning_rate': 0.5296269981829013, 'n_estimators': 265, 'min_child_weight': 8, 'subsample': 0.4612831876024353, 'colsample_bytree': 0.6787831634958765, 'reg_alpha': 0.7923494203546674, 'reg_lambda': 0.042644284638511804, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:46:11,296] Trial 5 finished with value: 0.5570503965716752 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 3, 'min_child_samples': 2, 'learning_rate': 0.1268911640073926, 'n_estimators': 1071, 'min_child_weight': 7, 'subsample': 0.5882884023792169, 'colsample_bytree': 0.45465382288551043, 'reg_alpha': 0.09056212751610958, 'reg_lambda': 0.6070470238728294, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:46:26,652] Trial 6 finished with value: 0.5743273002459427 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 2, 'learning_rate': 0.14542972309676366, 'n_estimators': 842, 'min_child_weight': 10, 'subsample': 0.502962235722254, 'colsample_bytree': 0.2425266977084046, 'reg_alpha': 0.5570912193658097, 'reg_lambda': 0.9098531188398107, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:46:36,469] Trial 7 finished with value: 0.6107962959478644 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 14, 'learning_rate': 0.24449753141044167, 'n_estimators': 1019, 'min_child_weight': 4, 'subsample': 0.855147305136382, 'colsample_bytree': 0.41287565500070805, 'reg_alpha': 0.4359872164560051, 'reg_lambda': 0.8755612309472564, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:46:39,899] Trial 8 finished with value: 0.6371950071373136 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 15, 'learning_rate': 0.44058817572815956, 'n_estimators': 275, 'min_child_weight': 3, 'subsample': 0.6776997959976289, 'colsample_bytree': 0.748630898884089, 'reg_alpha': 0.5557770326970387, 'reg_lambda': 0.4571510701218677, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:46:43,749] Trial 9 finished with value: 0.7392718047191268 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 4, 'learning_rate': 0.8125445843793515, 'n_estimators': 699, 'min_child_weight': 5, 'subsample': 0.4813737201494776, 'colsample_bytree': 0.9561870777241966, 'reg_alpha': 0.3345408537351617, 'reg_lambda': 0.7552385328817341, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:46:54,287] Trial 10 finished with value: 0.6526574600666925 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 12, 'learning_rate': 0.9215168807428943, 'n_estimators': 1851, 'min_child_weight': 1, 'subsample': 0.021436604822332173, 'colsample_bytree': 0.029447430006917574, 'reg_alpha': 0.9648220792780253, 'reg_lambda': 0.25881836951666903, 'random_state': 42}. Best is trial 1 with value: 0.4873542544825821.
# [I 2023-12-26 01:47:06,409] Trial 11 finished with value: 0.44452867547764474 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 5, 'learning_rate': 0.014708193383202003, 'n_estimators': 545, 'min_child_weight': 6, 'subsample': 0.9978626406541281, 'colsample_bytree': 0.18827363355677218, 'reg_alpha': 0.25757007451820474, 'reg_lambda': 0.3472601269285045, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:07,613] Trial 12 finished with value: 0.6371141847323657 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 5, 'learning_rate': 0.024364936955182465, 'n_estimators': 52, 'min_child_weight': 6, 'subsample': 0.9841723928222831, 'colsample_bytree': 0.026938492960778077, 'reg_alpha': 0.33718623341535237, 'reg_lambda': 0.3458525591946515, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:15,646] Trial 13 finished with value: 0.6712084745633641 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 11, 'learning_rate': 0.2991829174205338, 'n_estimators': 501, 'min_child_weight': 3, 'subsample': 0.762087129743463, 'colsample_bytree': 0.21609318011911716, 'reg_alpha': 0.20528293619766708, 'reg_lambda': 0.2661663220346687, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:24,387] Trial 14 finished with value: 0.5525788273363509 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 6, 'learning_rate': 0.187742152138139, 'n_estimators': 526, 'min_child_weight': 6, 'subsample': 0.9988193281741209, 'colsample_bytree': 0.20677234906144257, 'reg_alpha': 0.7150627710832749, 'reg_lambda': 0.4053637552678179, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:28,643] Trial 15 finished with value: 0.6916071126897064 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 10, 'learning_rate': 0.5653766915084453, 'n_estimators': 470, 'min_child_weight': 1, 'subsample': 0.8067229609243755, 'colsample_bytree': 0.31369337732474056, 'reg_alpha': 0.2342831575873417, 'reg_lambda': 0.20237588084473812, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:30,410] Trial 16 finished with value: 0.5811705969635893 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 7, 'learning_rate': 0.015737636967051324, 'n_estimators': 63, 'min_child_weight': 3, 'subsample': 0.6608758968592807, 'colsample_bytree': 0.12458281685793714, 'reg_alpha': 0.3954016041924031, 'reg_lambda': 0.6578559856151995, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:35,700] Trial 17 finished with value: 0.6352448931694906 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 3, 'min_child_samples': 4, 'learning_rate': 0.3164644885105491, 'n_estimators': 701, 'min_child_weight': 7, 'subsample': 0.30325131216876844, 'colsample_bytree': 0.5796348014478618, 'reg_alpha': 0.21709956278939496, 'reg_lambda': 0.3203452014516578, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:39,762] Trial 18 finished with value: 0.48679551186171116 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 1, 'learning_rate': 0.13189138961371044, 'n_estimators': 306, 'min_child_weight': 4, 'subsample': 0.9208119010880849, 'colsample_bytree': 0.347922797850565, 'reg_alpha': 0.915930528643722, 'reg_lambda': 0.14797943016750958, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:45,671] Trial 19 finished with value: 0.6393832026874937 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 1, 'learning_rate': 0.6695744114436273, 'n_estimators': 1832, 'min_child_weight': 4, 'subsample': 0.90315410727819, 'colsample_bytree': 0.379761174982768, 'reg_alpha': 0.8772270859696686, 'reg_lambda': 0.032707173208292986, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:52,155] Trial 20 finished with value: 0.5833973984288 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 3, 'learning_rate': 0.22836320475523478, 'n_estimators': 701, 'min_child_weight': 2, 'subsample': 0.9447335609522495, 'colsample_bytree': 0.32256271131067005, 'reg_alpha': 0.6595687088797477, 'reg_lambda': 0.13381269638998156, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:47:59,905] Trial 21 finished with value: 0.48639560020934747 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 1, 'learning_rate': 0.12176337068029938, 'n_estimators': 313, 'min_child_weight': 4, 'subsample': 0.745657062789226, 'colsample_bytree': 0.13333628770489314, 'reg_alpha': 0.9943188019013605, 'reg_lambda': 0.17595965021223248, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:48:04,807] Trial 22 finished with value: 0.45153316536582766 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 1, 'learning_rate': 0.09779810279911091, 'n_estimators': 193, 'min_child_weight': 4, 'subsample': 0.8610501976508321, 'colsample_bytree': 0.11200202292542183, 'reg_alpha': 0.9782353594623029, 'reg_lambda': 0.14593969315485744, 'random_state': 42}. Best is trial 11 with value: 0.44452867547764474.
# [I 2023-12-26 01:48:09,088] Trial 23 finished with value: 0.4429944843947868 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 3, 'learning_rate': 0.07202440532732357, 'n_estimators': 165, 'min_child_weight': 6, 'subsample': 0.7733802923480494, 'colsample_bytree': 0.11881402380263742, 'reg_alpha': 0.8032491195255633, 'reg_lambda': 0.4274530343576461, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:48:12,855] Trial 24 finished with value: 0.4437477738171081 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 3, 'learning_rate': 0.06385866279061954, 'n_estimators': 137, 'min_child_weight': 7, 'subsample': 0.815849274028788, 'colsample_bytree': 0.08313998812296997, 'reg_alpha': 0.8055785283103022, 'reg_lambda': 0.42369776210693855, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:48:19,595] Trial 25 finished with value: 0.5580534203571966 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 4, 'learning_rate': 0.4016830144304314, 'n_estimators': 538, 'min_child_weight': 7, 'subsample': 0.5943684793130936, 'colsample_bytree': 0.025977312275091542, 'reg_alpha': 0.7277930482687901, 'reg_lambda': 0.4535678753582394, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:48:23,216] Trial 26 finished with value: 0.5128940316419034 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 5, 'learning_rate': 0.27860663665905516, 'n_estimators': 132, 'min_child_weight': 8, 'subsample': 0.8421666607507935, 'colsample_bytree': 0.23124629169374272, 'reg_alpha': 0.8161381462429198, 'reg_lambda': 0.5381142609889465, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:48:36,194] Trial 27 finished with value: 0.49598297155568977 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 3, 'learning_rate': 0.06532630452439515, 'n_estimators': 448, 'min_child_weight': 7, 'subsample': 0.6250114609446439, 'colsample_bytree': 0.2782388230830029, 'reg_alpha': 0.8258621372471232, 'reg_lambda': 0.39619504068639244, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:48:40,872] Trial 28 finished with value: 0.4957718734053251 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 3, 'learning_rate': 0.19162765490479616, 'n_estimators': 171, 'min_child_weight': 6, 'subsample': 0.7068691995821748, 'colsample_bytree': 0.17776838646282106, 'reg_alpha': 0.7218199701567855, 'reg_lambda': 0.6782751156643734, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:48:50,777] Trial 29 finished with value: 0.599646493100292 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 6, 'learning_rate': 0.378422619718899, 'n_estimators': 1352, 'min_child_weight': 9, 'subsample': 0.35926215718841054, 'colsample_bytree': 0.07395890000065417, 'reg_alpha': 0.6313210784622988, 'reg_lambda': 0.4978495104648437, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:49:03,032] Trial 30 finished with value: 0.5769949108720261 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 5, 'learning_rate': 0.1873057307192498, 'n_estimators': 610, 'min_child_weight': 9, 'subsample': 0.806843727500902, 'colsample_bytree': 0.1588206470307586, 'reg_alpha': 0.46667462249428027, 'reg_lambda': 0.37371270037256743, 'random_state': 42}. Best is trial 23 with value: 0.4429944843947868.
# [I 2023-12-26 01:49:06,825] Trial 31 finished with value: 0.442562159725089 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 2, 'learning_rate': 0.07693438557578444, 'n_estimators': 153, 'min_child_weight': 6, 'subsample': 0.9147751758973693, 'colsample_bytree': 0.09006309880807817, 'reg_alpha': 0.9169168783149214, 'reg_lambda': 0.446597955382748, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:15,161] Trial 32 finished with value: 0.46017181207668556 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 2, 'learning_rate': 0.07435177415163007, 'n_estimators': 389, 'min_child_weight': 6, 'subsample': 0.9223849608218493, 'colsample_bytree': 0.08173023515150797, 'reg_alpha': 0.8971345391620117, 'reg_lambda': 0.4632899895134897, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:20,108] Trial 33 finished with value: 0.5232920330681378 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 3, 'learning_rate': 0.010124791241831362, 'n_estimators': 177, 'min_child_weight': 5, 'subsample': 0.7766332735591503, 'colsample_bytree': 0.07871132722843242, 'reg_alpha': 0.7731501379114607, 'reg_lambda': 0.5759843021057411, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:24,125] Trial 34 finished with value: 0.44437287652766205 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 7, 'learning_rate': 0.07064287357351916, 'n_estimators': 334, 'min_child_weight': 8, 'subsample': 0.992459870003134, 'colsample_bytree': 0.01456266251403214, 'reg_alpha': 0.8807060126427971, 'reg_lambda': 0.308464939991677, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:29,308] Trial 35 finished with value: 0.4439257985741327 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 7, 'learning_rate': 0.0759113947338584, 'n_estimators': 224, 'min_child_weight': 8, 'subsample': 0.9032736748375162, 'colsample_bytree': 0.06444162413880415, 'reg_alpha': 0.849335463439957, 'reg_lambda': 0.22581951800890288, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:32,331] Trial 36 finished with value: 0.4698425364376642 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 9, 'learning_rate': 0.17663226899968804, 'n_estimators': 61, 'min_child_weight': 7, 'subsample': 0.5590023745187371, 'colsample_bytree': 0.5863078521075806, 'reg_alpha': 0.8411255771315104, 'reg_lambda': 0.22618912486141995, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:48,439] Trial 37 finished with value: 0.5733443556538651 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 2, 'learning_rate': 0.24408136172177977, 'n_estimators': 1509, 'min_child_weight': 10, 'subsample': 0.888922115753642, 'colsample_bytree': 0.273595647608592, 'reg_alpha': 0.7654463658625112, 'reg_lambda': 0.41746768078740837, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:54,069] Trial 38 finished with value: 0.4478699549465584 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 7, 'learning_rate': 0.0826950150772888, 'n_estimators': 226, 'min_child_weight': 8, 'subsample': 0.822923747559988, 'colsample_bytree': 0.08087916129684874, 'reg_alpha': 0.9339284077775065, 'reg_lambda': 0.07326890708070027, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:49:59,846] Trial 39 finished with value: 0.5955852210568636 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 2, 'learning_rate': 0.33196338460643665, 'n_estimators': 376, 'min_child_weight': 9, 'subsample': 0.09584565757770241, 'colsample_bytree': 0.4702827545377204, 'reg_alpha': 0.6697910776686057, 'reg_lambda': 0.6134668979456284, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:50:06,071] Trial 40 finished with value: 0.6258447480140766 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 13, 'learning_rate': 0.46724168219674983, 'n_estimators': 862, 'min_child_weight': 5, 'subsample': 0.7102748170373914, 'colsample_bytree': 0.9287194757080837, 'reg_alpha': 0.5776773789173447, 'reg_lambda': 0.9711748451416775, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:50:09,847] Trial 41 finished with value: 0.445991821399107 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 7, 'learning_rate': 0.061267136469133315, 'n_estimators': 373, 'min_child_weight': 8, 'subsample': 0.8910807145371595, 'colsample_bytree': 0.021531959027082645, 'reg_alpha': 0.8569114154442072, 'reg_lambda': 0.30167057209234205, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:50:16,029] Trial 42 finished with value: 0.4858307038787555 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 9, 'learning_rate': 0.1405867519135134, 'n_estimators': 256, 'min_child_weight': 8, 'subsample': 0.9585553757551216, 'colsample_bytree': 0.1441585894572522, 'reg_alpha': 0.9441617205460113, 'reg_lambda': 0.5152703674546776, 'random_state': 42}. Best is trial 31 with value: 0.442562159725089.
# [I 2023-12-26 01:50:19,781] Trial 43 finished with value: 0.44220840444008463 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 8, 'learning_rate': 0.08802088296025533, 'n_estimators': 132, 'min_child_weight': 7, 'subsample': 0.9529296914826779, 'colsample_bytree': 0.07301986762794678, 'reg_alpha': 0.8855851075888906, 'reg_lambda': 0.244316292025276, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:50:23,393] Trial 44 finished with value: 0.4568954933263088 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 8, 'learning_rate': 0.1516201153080044, 'n_estimators': 134, 'min_child_weight': 7, 'subsample': 0.7841603679617454, 'colsample_bytree': 0.09073864212712585, 'reg_alpha': 0.7817674105456907, 'reg_lambda': 0.0954993972349649, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:50:26,805] Trial 45 finished with value: 0.4854663532246017 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 10, 'learning_rate': 0.23123028864961975, 'n_estimators': 119, 'min_child_weight': 7, 'subsample': 0.8607797321701934, 'colsample_bytree': 0.17472263072229643, 'reg_alpha': 0.9180383181637549, 'reg_lambda': 0.23664076559748853, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:50:35,010] Trial 46 finished with value: 0.48939294879550627 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 4, 'learning_rate': 0.10161940129283795, 'n_estimators': 246, 'min_child_weight': 6, 'subsample': 0.9460270829278217, 'colsample_bytree': 0.263139751471257, 'reg_alpha': 0.7472114866676404, 'reg_lambda': 0.4382016753816829, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:50:48,126] Trial 47 finished with value: 0.4646756188874701 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 8, 'learning_rate': 0.05998074082932316, 'n_estimators': 622, 'min_child_weight': 6, 'subsample': 0.8805004987778213, 'colsample_bytree': 0.06368778136842876, 'reg_alpha': 0.6852021527763815, 'reg_lambda': 0.35331746168648115, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:50:52,709] Trial 48 finished with value: 0.6539529934759281 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 6, 'learning_rate': 0.9815160289296375, 'n_estimators': 1011, 'min_child_weight': 7, 'subsample': 0.6786574510495074, 'colsample_bytree': 0.12902117644820366, 'reg_alpha': 0.8109932013835782, 'reg_lambda': 0.49993378813234685, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:50:57,530] Trial 49 finished with value: 0.6169111631224343 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 10, 'learning_rate': 0.7985724770846492, 'n_estimators': 1174, 'min_child_weight': 5, 'subsample': 0.7431898650147064, 'colsample_bytree': 0.20248379267315658, 'reg_alpha': 0.849520853975388, 'reg_lambda': 0.269046894210031, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:02,963] Trial 50 finished with value: 0.5847493917304368 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 11, 'learning_rate': 0.5920321610117553, 'n_estimators': 411, 'min_child_weight': 8, 'subsample': 0.836063972887009, 'colsample_bytree': 0.060143080205436336, 'reg_alpha': 0.9472977739471672, 'reg_lambda': 0.19320618724960364, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:07,698] Trial 51 finished with value: 0.4454703893849141 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 7, 'learning_rate': 0.06363659292457596, 'n_estimators': 302, 'min_child_weight': 10, 'subsample': 0.9604082640761797, 'colsample_bytree': 0.011283828341381419, 'reg_alpha': 0.887659626628176, 'reg_lambda': 0.3022840451657903, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:09,607] Trial 52 finished with value: 0.4500992382490981 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 9, 'learning_rate': 0.16105046498419795, 'n_estimators': 70, 'min_child_weight': 8, 'subsample': 0.9948568525321381, 'colsample_bytree': 0.04869118237787343, 'reg_alpha': 0.9943901961758239, 'reg_lambda': 0.3310571748304502, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:14,004] Trial 53 finished with value: 0.447264519995773 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 6, 'learning_rate': 0.03654122843269234, 'n_estimators': 201, 'min_child_weight': 9, 'subsample': 0.9393266405520647, 'colsample_bytree': 0.12772694231246584, 'reg_alpha': 0.7932625768852641, 'reg_lambda': 0.3683507679459676, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:17,754] Trial 54 finished with value: 0.44815522427450377 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 4, 'learning_rate': 0.10726656618420038, 'n_estimators': 314, 'min_child_weight': 7, 'subsample': 0.9147454536394262, 'colsample_bytree': 0.010800450640621809, 'reg_alpha': 0.8425634653144448, 'reg_lambda': 0.2474236816368401, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:20,988] Trial 55 finished with value: 0.46983545177983504 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 8, 'learning_rate': 0.22007970013568445, 'n_estimators': 122, 'min_child_weight': 6, 'subsample': 0.4273231883780444, 'colsample_bytree': 0.10393175495590021, 'reg_alpha': 0.8835435062341009, 'reg_lambda': 0.29089055312649614, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:25,048] Trial 56 finished with value: 0.48874360538205885 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 3, 'learning_rate': 0.11812608105787206, 'n_estimators': 232, 'min_child_weight': 8, 'subsample': 0.9759260060456401, 'colsample_bytree': 0.7179861074763731, 'reg_alpha': 0.8749912330926657, 'reg_lambda': 0.3953502293727251, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:34,651] Trial 57 finished with value: 0.4515251062837778 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 5, 'learning_rate': 0.04242096420960782, 'n_estimators': 329, 'min_child_weight': 5, 'subsample': 0.8076210409714298, 'colsample_bytree': 0.1584066443469377, 'reg_alpha': 0.9521685281998757, 'reg_lambda': 0.47840229680915003, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:37,713] Trial 58 finished with value: 0.4758750745318379 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 2, 'learning_rate': 0.26458803832860756, 'n_estimators': 54, 'min_child_weight': 7, 'subsample': 0.8599518412107665, 'colsample_bytree': 0.23089383615274967, 'reg_alpha': 0.030450919006454746, 'reg_lambda': 0.42757456470098654, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:46,277] Trial 59 finished with value: 0.5225676412787031 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 7, 'learning_rate': 0.13738987233396505, 'n_estimators': 438, 'min_child_weight': 6, 'subsample': 0.1656566444924546, 'colsample_bytree': 0.19591644582776863, 'reg_alpha': 0.912274186766629, 'reg_lambda': 0.20032163006039042, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:51:51,936] Trial 60 finished with value: 0.48572905141274375 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 1, 'learning_rate': 0.010030556827934085, 'n_estimators': 166, 'min_child_weight': 8, 'subsample': 0.9119269325304213, 'colsample_bytree': 0.8171521936181037, 'reg_alpha': 0.6004489072190904, 'reg_lambda': 0.3178715605176139, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:52:14,240] Trial 61 finished with value: 0.5606942129288229 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 5, 'learning_rate': 0.08949389273719766, 'n_estimators': 1995, 'min_child_weight': 6, 'subsample': 0.9960021945833955, 'colsample_bytree': 0.04984041073801906, 'reg_alpha': 0.1727589279053624, 'reg_lambda': 0.35232427095188823, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:52:26,633] Trial 62 finished with value: 0.4563520340728146 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 6, 'learning_rate': 0.040149708803774026, 'n_estimators': 569, 'min_child_weight': 7, 'subsample': 0.9591799727484537, 'colsample_bytree': 0.11242760708027436, 'reg_alpha': 0.30599119912615286, 'reg_lambda': 0.3966323681402831, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:52:40,513] Trial 63 finished with value: 0.5482889411836531 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 4, 'learning_rate': 0.09905395933096965, 'n_estimators': 767, 'min_child_weight': 7, 'subsample': 0.893339532240031, 'colsample_bytree': 0.1682101029728347, 'reg_alpha': 0.38577454948077555, 'reg_lambda': 0.28246682881822877, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:52:47,383] Trial 64 finished with value: 0.5226363924756379 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 3, 'learning_rate': 0.21318893734316186, 'n_estimators': 460, 'min_child_weight': 6, 'subsample': 0.9312574955914175, 'colsample_bytree': 0.04672259479989416, 'reg_alpha': 0.5245808315503292, 'reg_lambda': 0.16264285727479505, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:52:51,486] Trial 65 finished with value: 0.48034832029863667 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 8, 'learning_rate': 0.1673454359997049, 'n_estimators': 247, 'min_child_weight': 5, 'subsample': 0.7821455871025206, 'colsample_bytree': 0.10543823633224311, 'reg_alpha': 0.13666447234752066, 'reg_lambda': 0.560673579579446, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:01,237] Trial 66 finished with value: 0.4519145373652957 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 5, 'learning_rate': 0.011098830280781562, 'n_estimators': 345, 'min_child_weight': 6, 'subsample': 0.9804512448147943, 'colsample_bytree': 0.3170039825959481, 'reg_alpha': 0.2855874329275682, 'reg_lambda': 0.22247648842690046, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:04,294] Trial 67 finished with value: 0.4548009327506984 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 7, 'learning_rate': 0.05052967307205147, 'n_estimators': 116, 'min_child_weight': 7, 'subsample': 0.838513599254618, 'colsample_bytree': 0.5383251946283366, 'reg_alpha': 0.8115773287853402, 'reg_lambda': 0.46070581820070816, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:15,732] Trial 68 finished with value: 0.5237244477646406 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 4, 'learning_rate': 0.12523170779671722, 'n_estimators': 521, 'min_child_weight': 8, 'subsample': 0.8759356202478505, 'colsample_bytree': 0.14393946781299166, 'reg_alpha': 0.7253029337606292, 'reg_lambda': 0.3847993166664495, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:23,008] Trial 69 finished with value: 0.4745106223644824 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 15, 'learning_rate': 0.08580465693108869, 'n_estimators': 279, 'min_child_weight': 9, 'subsample': 0.9436103275759754, 'colsample_bytree': 0.197855650500485, 'reg_alpha': 0.7481528485023011, 'reg_lambda': 0.34214548187293115, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:24,966] Trial 70 finished with value: 0.4727343991834705 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 3, 'min_child_samples': 2, 'learning_rate': 0.19646625647850097, 'n_estimators': 198, 'min_child_weight': 5, 'subsample': 0.9218541801789332, 'colsample_bytree': 0.40094658503042424, 'reg_alpha': 0.44437612349519534, 'reg_lambda': 0.42543955644381054, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:28,598] Trial 71 finished with value: 0.44487838378007094 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 7, 'learning_rate': 0.06423024432407479, 'n_estimators': 300, 'min_child_weight': 9, 'subsample': 0.9066389764103134, 'colsample_bytree': 0.013361380799476885, 'reg_alpha': 0.9066491212182235, 'reg_lambda': 0.31007412836582093, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:34,296] Trial 72 finished with value: 0.4436358143598229 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 6, 'learning_rate': 0.046171868361838, 'n_estimators': 398, 'min_child_weight': 10, 'subsample': 0.9748842670439213, 'colsample_bytree': 0.0883814113113241, 'reg_alpha': 0.859840392220163, 'reg_lambda': 0.2607895665243638, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:39,857] Trial 73 finished with value: 0.4435446721973782 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 6, 'learning_rate': 0.03084002250532766, 'n_estimators': 365, 'min_child_weight': 10, 'subsample': 0.9729654377538756, 'colsample_bytree': 0.09101770125117628, 'reg_alpha': 0.863236669224335, 'reg_lambda': 0.11183595008574987, 'random_state': 42}. Best is trial 43 with value: 0.44220840444008463.
# [I 2023-12-26 01:53:46,683] Trial 74 finished with value: 0.4419966678998551 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 6, 'learning_rate': 0.03449815999986062, 'n_estimators': 386, 'min_child_weight': 10, 'subsample': 0.974666353158311, 'colsample_bytree': 0.09240704638465902, 'reg_alpha': 0.8664857910079182, 'reg_lambda': 0.10783948587916464, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:53:51,267] Trial 75 finished with value: 0.4450047841389997 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 6, 'learning_rate': 0.043534868644720864, 'n_estimators': 407, 'min_child_weight': 10, 'subsample': 0.9628661216266287, 'colsample_bytree': 0.08780131257634514, 'reg_alpha': 0.861086200193619, 'reg_lambda': 0.018166309258011895, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:53:53,468] Trial 76 finished with value: 0.4464206628433871 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 6, 'learning_rate': 0.11535558008575311, 'n_estimators': 163, 'min_child_weight': 10, 'subsample': 0.8233830983548922, 'colsample_bytree': 0.11042677840370824, 'reg_alpha': 0.8233199726251248, 'reg_lambda': 0.11065704847232982, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:53:55,250] Trial 77 finished with value: 0.447531416108858 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 5, 'learning_rate': 0.159403680052275, 'n_estimators': 101, 'min_child_weight': 10, 'subsample': 0.8697361735220261, 'colsample_bytree': 0.061134383952968774, 'reg_alpha': 0.9732669729677396, 'reg_lambda': 0.07199320384687558, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:53:59,188] Trial 78 finished with value: 0.4515499448920061 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 8, 'learning_rate': 0.02883473461115161, 'n_estimators': 215, 'min_child_weight': 10, 'subsample': 0.7622427466657101, 'colsample_bytree': 0.15057776283987728, 'reg_alpha': 0.6945954222254351, 'reg_lambda': 0.08223963116676215, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:04,476] Trial 79 finished with value: 0.47410952552684177 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 6, 'learning_rate': 0.08861165326692932, 'n_estimators': 475, 'min_child_weight': 9, 'subsample': 0.9001137694442481, 'colsample_bytree': 0.2504754275040155, 'reg_alpha': 0.7977810124939773, 'reg_lambda': 0.1285124934882814, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:18,107] Trial 80 finished with value: 0.45348315878205203 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 3, 'learning_rate': 0.035041858294744044, 'n_estimators': 1497, 'min_child_weight': 9, 'subsample': 0.9337090824004944, 'colsample_bytree': 0.040416426631900995, 'reg_alpha': 0.9190715524103151, 'reg_lambda': 0.15651515373350644, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:25,953] Trial 81 finished with value: 0.4619623200931904 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 7, 'learning_rate': 0.0730240256188457, 'n_estimators': 610, 'min_child_weight': 10, 'subsample': 0.9727996596103021, 'colsample_bytree': 0.08787425964923354, 'reg_alpha': 0.8562536772916247, 'reg_lambda': 0.18170875811182596, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:29,334] Trial 82 finished with value: 0.45165673637282816 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 7, 'learning_rate': 0.13765667439792462, 'n_estimators': 350, 'min_child_weight': 10, 'subsample': 0.9815908535626331, 'colsample_bytree': 0.03560411889675113, 'reg_alpha': 0.7570723006712375, 'reg_lambda': 0.05521498706375334, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:33,014] Trial 83 finished with value: 0.4439273358032238 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 9, 'learning_rate': 0.08303460557201126, 'n_estimators': 159, 'min_child_weight': 9, 'subsample': 0.8535390903484098, 'colsample_bytree': 0.06808464116870816, 'reg_alpha': 0.8325994253847232, 'reg_lambda': 0.2510417343384523, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:37,246] Trial 84 finished with value: 0.4544837057982478 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 9, 'learning_rate': 0.10795251052456754, 'n_estimators': 148, 'min_child_weight': 9, 'subsample': 0.8534948361787338, 'colsample_bytree': 0.13036157019356945, 'reg_alpha': 0.8342716840441483, 'reg_lambda': 0.2102796081153586, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:41,236] Trial 85 finished with value: 0.6421765226328406 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 8, 'learning_rate': 0.8478455482100182, 'n_estimators': 268, 'min_child_weight': 10, 'subsample': 0.8854661792471581, 'colsample_bytree': 0.09113481943193633, 'reg_alpha': 0.7904162072212791, 'reg_lambda': 0.26371245672508903, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:43,596] Trial 86 finished with value: 0.460476458494139 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 9, 'learning_rate': 0.0743284195249335, 'n_estimators': 88, 'min_child_weight': 9, 'subsample': 0.8027739932688411, 'colsample_bytree': 0.06927897800487594, 'reg_alpha': 0.9319200084826738, 'reg_lambda': 0.5322969757368257, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:50,272] Trial 87 finished with value: 0.44963504758691014 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 2, 'learning_rate': 0.027967348530160516, 'n_estimators': 193, 'min_child_weight': 10, 'subsample': 0.7084160083382631, 'colsample_bytree': 0.176255174397687, 'reg_alpha': 0.8969152009193416, 'reg_lambda': 0.10238491803250917, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:54:58,592] Trial 88 finished with value: 0.5208017739286069 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 11, 'learning_rate': 0.182067546079407, 'n_estimators': 382, 'min_child_weight': 9, 'subsample': 0.5473047986910033, 'colsample_bytree': 0.11394494914006255, 'reg_alpha': 0.863170129196861, 'reg_lambda': 0.2402483698567174, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:01,524] Trial 89 finished with value: 0.44981688452593893 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 1, 'learning_rate': 0.1509398037468242, 'n_estimators': 271, 'min_child_weight': 10, 'subsample': 0.9328634132611513, 'colsample_bytree': 0.06589456976672387, 'reg_alpha': 0.955580582591473, 'reg_lambda': 0.712271293366314, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:04,304] Trial 90 finished with value: 0.6263946071423153 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 10, 'learning_rate': 0.7274716684540663, 'n_estimators': 153, 'min_child_weight': 2, 'subsample': 0.7297662475791603, 'colsample_bytree': 0.29434465939010546, 'reg_alpha': 0.8278046478437185, 'reg_lambda': 0.17356696108934005, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:07,881] Trial 91 finished with value: 0.45401929939289154 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 8, 'learning_rate': 0.053436993561442214, 'n_estimators': 226, 'min_child_weight': 8, 'subsample': 0.9930520112081493, 'colsample_bytree': 0.04004130801153074, 'reg_alpha': 0.8748517406189747, 'reg_lambda': 0.27408905139023865, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:09,069] Trial 92 finished with value: 0.5217345782762148 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 6, 'learning_rate': 0.08286254318685585, 'n_estimators': 51, 'min_child_weight': 8, 'subsample': 0.9557000231337563, 'colsample_bytree': 0.03137628219642158, 'reg_alpha': 0.895591371110411, 'reg_lambda': 0.2208641372511566, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:18,459] Trial 93 finished with value: 0.5000998273125111 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 9, 'min_child_samples': 7, 'learning_rate': 0.12139214981268683, 'n_estimators': 352, 'min_child_weight': 9, 'subsample': 0.9095607100954397, 'colsample_bytree': 0.1342394224236684, 'reg_alpha': 0.7811374314689776, 'reg_lambda': 0.3677235391065988, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:21,289] Trial 94 finished with value: 0.45637510572024964 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 8, 'min_child_samples': 9, 'learning_rate': 0.05090959802382824, 'n_estimators': 98, 'min_child_weight': 7, 'subsample': 0.8224548665911668, 'colsample_bytree': 0.09628652168097884, 'reg_alpha': 0.9743312462277118, 'reg_lambda': 0.2478840661486737, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:27,732] Trial 95 finished with value: 0.4811287151101262 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 6, 'min_child_samples': 3, 'learning_rate': 0.09916767002639001, 'n_estimators': 326, 'min_child_weight': 8, 'subsample': 0.966804689330378, 'colsample_bytree': 0.2214710316446005, 'reg_alpha': 0.9320829147369636, 'reg_lambda': 0.134171807311734, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:32,939] Trial 96 finished with value: 0.4465678764860881 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 7, 'min_child_samples': 8, 'learning_rate': 0.07648957398669709, 'n_estimators': 418, 'min_child_weight': 10, 'subsample': 0.8477949085624101, 'colsample_bytree': 0.010170755176971732, 'reg_alpha': 0.8091553074699618, 'reg_lambda': 0.44807940389402123, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:38,068] Trial 97 finished with value: 0.502121398943813 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 10, 'min_child_samples': 4, 'learning_rate': 0.011880981863674145, 'n_estimators': 194, 'min_child_weight': 7, 'subsample': 0.8749321380063559, 'colsample_bytree': 0.07701595523145338, 'reg_alpha': 0.8378238216480154, 'reg_lambda': 0.3212131129742878, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:46,435] Trial 98 finished with value: 0.4660697070049445 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 5, 'min_child_samples': 5, 'learning_rate': 0.030666883799753693, 'n_estimators': 488, 'min_child_weight': 8, 'subsample': 0.99959162629427, 'colsample_bytree': 0.9166606640499169, 'reg_alpha': 0.880816711667828, 'reg_lambda': 0.18611908357756785, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# [I 2023-12-26 01:55:50,789] Trial 99 finished with value: 0.5552474322525929 and parameters: {'objective': 'multi_logloss', 'num_class': 3, 'max_depth': 4, 'min_child_samples': 7, 'learning_rate': 0.4767535915792048, 'n_estimators': 285, 'min_child_weight': 9, 'subsample': 0.9496815833502347, 'colsample_bytree': 0.15605080063387944, 'reg_alpha': 0.8522003519864769, 'reg_lambda': 0.47840182140962234, 'random_state': 42}. Best is trial 74 with value: 0.4419966678998551.
# CPU times: user 38min 59s, sys: 1min 11s, total: 40min 10s
# Wall time: 10min 53s

# %%
# [I 2023-12-22 04:24:17,624] Trial 88 finished with value: 0.4414199165690038 and 
lgbm_params = {'objective': 'multi_logloss', 
             'max_depth': 7, 'min_child_samples': 11, 
             'learning_rate': 0.01566483845941954, 
             'n_estimators': 966, 'min_child_weight': 9, 
             'subsample': 0.45579910488195635, 
             'colsample_bytree': 0.0757022595046426, 
             'reg_alpha': 0.9766398799933541, 
             'reg_lambda': 0.48128958254209964, 
             'random_state': 42}
#         . Best is trial 88 with value: 0.4414199165690038.

lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model.fit(X, y)
# Out:
# LGBMClassifier(colsample_bytree=0.0757022595046426,
#                learning_rate=0.01566483845941954, max_depth=7,
#                min_child_samples=11, min_child_weight=9, n_estimators=966,
#                objective='multi_logloss', random_state=42,
#                reg_alpha=0.9766398799933541, reg_lambda=0.48128958254209964,
#                subsample=0.45579910488195635)

# %%
log_loss(y_test, lgbm_model.predict_proba(X_test))
# Out:
# 0.2723159926186088

# %%
preds = lgbm_model.predict_proba(test_x)
preds = pd.DataFrame(preds, columns = ['C', 'CL', 'D'])
sub = pd.DataFrame(test_id)
sub['Status_C'] = preds['C']
sub['Status_CL'] = preds['CL']
sub['Status_D'] = preds['D']

# %%
sub.to_csv('submission.csv', index = False)
sub
# Out:
#          id  Status_C  Status_CL  Status_D
# 0      7905  0.404974   0.026254  0.568772
# 1      7906  0.530175   0.315279  0.154546
# 2      7907  0.032800   0.011667  0.955533
# 3      7908  0.962628   0.001809  0.035563
# 4      7909  0.845414   0.074500  0.080086
# ...     ...       ...        ...       ...
# 5266  13171  0.887824   0.062986  0.049190
# 5267  13172  0.961122   0.005225  0.033653
# 5268  13173  0.937622   0.012519  0.049859
# 5269  13174  0.985749   0.004498  0.009753
# 5270  13175  0.512885   0.032193  0.454922
#
# [5271 rows x 4 columns]
